# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
req = requests.get("http://medicine.iu.edu/departments/surgery/faculty/")
soup = BeautifulSoup(req.text, "lxml")

# %%
faculty_list = []
for child in soup.h4.children:
    faculty_list.append(child)

# %% [markdown]
# ### Find all the faculty sub-urls and add the appropriate root URL.

# %%
sub_links = soup.select('h4 a')

full_links = []
names = []
for sl in sub_links:
    full_links.append('http://medicine.iu.edu/departments/surgery/faculty/' + sl['href'])
    names.append(sl.get_text())
print('# Names: ' + str(len(names)) + ', # Links: ' + str(len(full_links)))
print('Last Name: ' + names[-1])
print('Last link: ' + full_links[-1])
# Out:
# # Names: 113, # Links: 113
# Last Name: Nicholas J. Zyromski, MD
# Last link: http://medicine.iu.edu/departments/surgery/faculty/17324/zyromski-nicholas/

# %% [markdown]
# ### Setup a dataframe

# %%
faculty = pd.DataFrame({
    "name": names,
    "webpage": full_links
})
faculty['name'][0]
faculty['webpage'][0]
# Out:
# 'Joshua M. Adkinson, MD'

# %% [markdown]
# #### Progress bar code from https://github.com/alexanderkuk/log-progress

# %%
def log_progress(sequence, every=None, size=None, name='Items'):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{name}: {index} / ?'.format(
                        name=name,
                        index=index
                    )
                else:
                    progress.value = index
                    label.value = u'{name}: {index} / {size}'.format(
                        name=name,
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = "{name}: {index}".format(
            name=name,
            index=str(index or '?')
        )

# %% [markdown]
# ### Request faculty pages

# %%
page_reqs = []

for link in log_progress(full_links, every=1):
    page_reqs.append(requests.get(link))

# %% [markdown]
# ### Parse all the requests

# %%
soups = []

for req in log_progress(page_reqs, every=1):
    soups.append(BeautifulSoup(req.text, 'html.parser'))

# %% [markdown]
# ### Extract pubmed links

# %%
pubmed_links = []
for i in range(len(soups)):
    soup = soups[i]
    pubmed_links.append([])
    possible_pubmed_links = soup.select('#region-main div div div a')
    for l in possible_pubmed_links:       
        if 'ncbi.nlm.nih.gov/pubmed' in l['href']:
            for c in l.children:
                if c.name == 'img':
                    pubmed_links[i].append(l['href'])
faculty['pubmed'] = pubmed_links
# Out:
# # PB links: 113

# %% [markdown]
# ### Request Pubmed Pages

# %%
pubmed_reqs = []
num_valid = 0
for i in log_progress(range(len(faculty)), every=1):
    if pubmed_links[i] == []:
        pubmed_reqs.append(None)
    else:
        pubmed_reqs.append(requests.get(pubmed_links[i][0]))
        num_valid += 1

# %% [markdown]
# ### Parse Pubmed Requests

# %%
soups = []

for req in log_progress(pubmed_reqs, every=1):
    if req != None:
        soups.append(BeautifulSoup(req.text, 'html.parser'))
    else:
        soups.append(None)

# %% [markdown]
# ### Extract number of search results

# %%
test = soups[2].find_all('h3', class_='result_count')
a = test[0].get_text()
a = 'hello 32'
b = [int(s) for s in a.split() if s.isdigit()]
b
# Out:
# [32]

# %%
num_publications = []
for i in log_progress(range(len(soups)), every=1):
    if soups[i] != None:
        result_count = soups[i].find_all('h3', class_='result_count')
        # If it didn't find anything, that means it was a link to a paper. So the count is one.
        if result_count == []:
            num_publications.append(1)
            continue
        result_count_str = result_count[0].get_text()
        parsed_publications = [int(s) for s in result_count_str.split() if s.isdigit()]
        # Last one is the final count
        num_publications.append(parsed_publications[-1])
    else:
        num_publications.append(None)
faculty['pubs'] = num_publications

# %% [markdown]
# ### Cleanup and Save the DataFrame

# %%
cleaned_pubmed = []
for i in range(len(pubmed_links)):
    if len(pubmed_links[i])>0 :
        cleaned_pubmed.append(pubmed_links[i][0])
    else:
        cleaned_pubmed.append(None)
faculty['pubmed'] = cleaned_pubmed
faculty
# Out:
#                                    name  \
# 0                Joshua M. Adkinson, MD
# 1                    Ambar Banerjee, MD
# 2            Christopher M. Bearden, MD
# 3                 Daniel J. Beckman, MD
# 4                   Teresa M. Bell, PhD
# 5               Deborah F. Billmire, MD
# 6                  Thomas J. Birdas, MD
# 7                   Andrea Bonetto, PhD
# 8                   Brian L. Brewer, MD
# 9                     John W. Brown, MD
# 10                Jeffrey S. Browne, MD
# 11          Claire E. Burgardt, MD,  AS
# 12                       R C. Burns, MD
# 13              Annabelle R. Butler, MD
# 14                   David F. Canal, MD
# 15                DuyKhanh P. Ceppa, MD
# 16                  Eugene P. Ceppa, MD
# 17                 Jennifer N. Choi, MD
# 18                 Jamie J. Coleman, MD
# 19                  Joel S. Corvera, MD
# 20               Michael C. Dalsing, MD
# 21               Gary L. Dunnington, MD
# 22                Burcin Ekser, MD, PhD
# 23                 Jeffrey E. Everett,
# 24                Alyssa D. Fajardo, MD
# 25                   Andres Fajardo, MD
# 26               Mark E. Falimirski, MD
# 27                  Carla S. Fisher, MD
# 28              Jonathan A. Fridell, MD
# 29                 Sidhbh Gallagher, MD
# ..                                  ...
# 83              Rachel D. Rodriguez, MD
# 84                    Dale A. Rouch, MD
# 85                  Thomas M. Rouse, MD
# 86                 Grace S. Rozycki, MD
# 87              Stephanie A. Savage, MD
# 88                  Alan P. Sawchuk, MD
# 89                C M. Schmidt, MD, PhD
# 90      Douglas J. Schwartzentruber, MD
# 91          Don J. Selzer, BS,  MD,  MS
# 92                  Clark J. Simons, MD
# 93                     N. J. Skill, PhD
# 94                       Juan Socas, MD
# 95                       Rajiv Sood, MD
# 96           Katie J. Stanton-Maxey, MD
# 97         Dimitrios Stefanidis, MD PhD
# 98                 Larry H. Stevens, MD
# 99                   Erik W. Streib, MD
# 100  Sunil Tholpady, MD, PhD,  PhD,  MS
# 101              Mark W. Turrentine, MD
# 102              Joseph L. Unthank, PhD
# 103                 I-Wen Wang, MD, PhD
# 104                    Meijing Wang, MD
# 105                Joshua A. Waters, MD
# 106               William A. Wooden, MD
# 107       Michele T. Yip-Schneider, PhD
# 108            Ben L. Zarzaur, MD,  MPH
# 109            Xiao-Ling Zhong, MD, PhD
# 110          Michael A. Zieger, MD, PhD
# 111              Teresa A. Zimmers, PhD
# 112            Nicholas J. Zyromski, MD
#
#                                                webpage  \
# 0    http://medicine.iu.edu/departments/surgery/fac...
# 1    http://medicine.iu.edu/departments/surgery/fac...
# 2    http://medicine.iu.edu/departments/surgery/fac...
# 3    http://medicine.iu.edu/departments/surgery/fac...
# 4    http://medicine.iu.edu/departments/surgery/fac...
# 5    http://medicine.iu.edu/departments/surgery/fac...
# 6    http://medicine.iu.edu/departments/surgery/fac...
# 7    http://medicine.iu.edu/departments/surgery/fac...
# 8    http://medicine.iu.edu/departments/surgery/fac...
# 9    http://medicine.iu.edu/departments/surgery/fac...
# 10   http://medicine.iu.edu/departments/surgery/fac...
# 11   http://medicine.iu.edu/departments/surgery/fac...
# 12   http://medicine.iu.edu/departments/surgery/fac...
# 13   http://medicine.iu.edu/departments/surgery/fac...
# 14   http://medicine.iu.edu/departments/surgery/fac...
# 15   http://medicine.iu.edu/departments/surgery/fac...
# 16   http://medicine.iu.edu/departments/surgery/fac...
# 17   http://medicine.iu.edu/departments/surgery/fac...
# 18   http://medicine.iu.edu/departments/surgery/fac...
# 19   http://medicine.iu.edu/departments/surgery/fac...
# 20   http://medicine.iu.edu/departments/surgery/fac...
# 21   http://medicine.iu.edu/departments/surgery/fac...
# 22   http://medicine.iu.edu/departments/surgery/fac...
# 23   http://medicine.iu.edu/departments/surgery/fac...
# 24   http://medicine.iu.edu/departments/surgery/fac...
# 25   http://medicine.iu.edu/departments/surgery/fac...
# 26   http://medicine.iu.edu/departments/surgery/fac...
# 27   http://medicine.iu.edu/departments/surgery/fac...
# 28   http://medicine.iu.edu/departments/surgery/fac...
# 29   http://medicine.iu.edu/departments/surgery/fac...
# ..                                                 ...
# 83   http://medicine.iu.edu/departments/surgery/fac...
# 84   http://medicine.iu.edu/departments/surgery/fac...
# 85   http://medicine.iu.edu/departments/surgery/fac...
# 86   http://medicine.iu.edu/departments/surgery/fac...
# 87   http://medicine.iu.edu/departments/surgery/fac...
# 88   http://medicine.iu.edu/departments/surgery/fac...
# 89   http://medicine.iu.edu/departments/surgery/fac...
# 90   http://medicine.iu.edu/departments/surgery/fac...
# 91   http://medicine.iu.edu/departments/surgery/fac...
# 92   http://medicine.iu.edu/departments/surgery/fac...
# 93   http://medicine.iu.edu/departments/surgery/fac...
# 94   http://medicine.iu.edu/departments/surgery/fac...
# 95   http://medicine.iu.edu/departments/surgery/fac...
# 96   http://medicine.iu.edu/departments/surgery/fac...
# 97   http://medicine.iu.edu/departments/surgery/fac...
# 98   http://medicine.iu.edu/departments/surgery/fac...
# 99   http://medicine.iu.edu/departments/surgery/fac...
# 100  http://medicine.iu.edu/departments/surgery/fac...
# 101  http://medicine.iu.edu/departments/surgery/fac...
# 102  http://medicine.iu.edu/departments/surgery/fac...
# 103  http://medicine.iu.edu/departments/surgery/fac...
# 104  http://medicine.iu.edu/departments/surgery/fac...
# 105  http://medicine.iu.edu/departments/surgery/fac...
# 106  http://medicine.iu.edu/departments/surgery/fac...
# 107  http://medicine.iu.edu/departments/surgery/fac...
# 108  http://medicine.iu.edu/departments/surgery/fac...
# 109  http://medicine.iu.edu/departments/surgery/fac...
# 110  http://medicine.iu.edu/departments/surgery/fac...
# 111  http://medicine.iu.edu/departments/surgery/fac...
# 112  http://medicine.iu.edu/departments/surgery/fac...
#
#                                                 pubmed   pubs
# 0    https://www.ncbi.nlm.nih.gov/pubmed/?term=Adki...    4.0
# 1    https://www.ncbi.nlm.nih.gov/pubmed/?term=Bane...   22.0
# 2    https://www.ncbi.nlm.nih.gov/pubmed/?term=Bear...    6.0
# 3    https://www.ncbi.nlm.nih.gov/pubmed/?term=Beck...   10.0
# 4                                                 None    NaN
# 5    https://www.ncbi.nlm.nih.gov/pubmed/?term=Bill...   17.0
# 6    https://www.ncbi.nlm.nih.gov/pubmed/?term=Bird...   16.0
# 7    https://www.ncbi.nlm.nih.gov/pubmed/?term=bone...   24.0
# 8    https://www.ncbi.nlm.nih.gov/pubmed/?term=Brew...    4.0
# 9    https://www.ncbi.nlm.nih.gov/pubmed/?term=Brow...  215.0
# 10   https://www.ncbi.nlm.nih.gov/pubmed/?term=Brow...    2.0
# 11   https://www.ncbi.nlm.nih.gov/pubmed/?term=Burg...    0.0
# 12   https://www.ncbi.nlm.nih.gov/pubmed/?term=Burn...    1.0
# 13   https://www.ncbi.nlm.nih.gov/pubmed/?term=Butl...    0.0
# 14   https://www.ncbi.nlm.nih.gov/pubmed/?term=Cana...   22.0
# 15   https://www.ncbi.nlm.nih.gov/pubmed/?term=Cepp...    9.0
# 16   https://www.ncbi.nlm.nih.gov/pubmed/?term=ceppa+e   59.0
# 17   https://www.ncbi.nlm.nih.gov/pubmed/?term=Choi...    5.0
# 18   https://www.ncbi.nlm.nih.gov/pubmed/?term=Cole...   46.0
# 19   https://www.ncbi.nlm.nih.gov/pubmed/?term=Corv...    5.0
# 20   https://www.ncbi.nlm.nih.gov/pubmed/?term=Dals...   92.0
# 21   https://www.ncbi.nlm.nih.gov/pubmed/?term=Dunn...   12.0
# 22   https://www.ncbi.nlm.nih.gov/pubmed/?term=Ekse...   21.0
# 23                                                None    NaN
# 24   https://www.ncbi.nlm.nih.gov/pubmed/?term=Faja...    5.0
# 25   https://www.ncbi.nlm.nih.gov/pubmed/?term=Faja...   15.0
# 26   https://www.ncbi.nlm.nih.gov/pubmed/?term=Fali...    4.0
# 27                                                None    NaN
# 28   https://www.ncbi.nlm.nih.gov/pubmed/?term=Frid...   87.0
# 29   https://www.ncbi.nlm.nih.gov/pubmed/?term=Gall...    0.0
# ..                                                 ...    ...
# 83   https://www.ncbi.nlm.nih.gov/pubmed/?term=Rodr...    1.0
# 84   https://www.ncbi.nlm.nih.gov/pubmed/?term=Rouc...    2.0
# 85   https://www.ncbi.nlm.nih.gov/pubmed/?term=Rous...   10.0
# 86   https://www.ncbi.nlm.nih.gov/pubmed/?term=Rozy...   12.0
# 87   https://www.ncbi.nlm.nih.gov/pubmed/?term=Sava...    9.0
# 88   https://www.ncbi.nlm.nih.gov/pubmed/?term=Sawc...   37.0
# 89   https://www.ncbi.nlm.nih.gov/pubmed/?term=Schm...  127.0
# 90   https://www.ncbi.nlm.nih.gov/pubmed/?term=Schw...    1.0
# 91   https://www.ncbi.nlm.nih.gov/pubmed/?term=Selz...   19.0
# 92   https://www.ncbi.nlm.nih.gov/pubmed/?term=Simo...    4.0
# 93   https://www.ncbi.nlm.nih.gov/pubmed/?term=Skil...   11.0
# 94   https://www.ncbi.nlm.nih.gov/pubmed/?term=Soca...   14.0
# 95   https://www.ncbi.nlm.nih.gov/pubmed/?term=Sood...   38.0
# 96   https://www.ncbi.nlm.nih.gov/pubmed/?term=Stan...    2.0
# 97   https://www.ncbi.nlm.nih.gov/pubmed/?term=Stef...   17.0
# 98   https://www.ncbi.nlm.nih.gov/pubmed/?term=Stev...   12.0
# 99   https://www.ncbi.nlm.nih.gov/pubmed/?term=Stre...    4.0
# 100  https://www.ncbi.nlm.nih.gov/pubmed/?term=thol...   85.0
# 101  https://www.ncbi.nlm.nih.gov/pubmed/?term=Turr...   98.0
# 102  https://www.ncbi.nlm.nih.gov/pubmed/?term=Unth...   54.0
# 103  https://www.ncbi.nlm.nih.gov/pubmed/?term=Wang...   13.0
# 104  https://www.ncbi.nlm.nih.gov/pubmed/?term=Wang...  422.0
# 105                                               None    NaN
# 106  https://www.ncbi.nlm.nih.gov/pubmed/?term=Wood...    5.0
# 107  https://www.ncbi.nlm.nih.gov/pubmed/?term=Yip-...   36.0
# 108  https://www.ncbi.nlm.nih.gov/pubmed/?term=(Zar...  119.0
# 109  https://www.ncbi.nlm.nih.gov/pubmed/?term=Zhon...   20.0
# 110  https://www.ncbi.nlm.nih.gov/pubmed/?term=Zieg...   16.0
# 111                                               None    NaN
# 112  https://www.ncbi.nlm.nih.gov/pubmed/?term=Zyro...   94.0
#
# [113 rows x 4 columns]

# %%
writer = pd.ExcelWriter('IndianaSurgeryFacultyInfo.xlsx')
faculty.to_excel(writer,'Sheet1')
writer.save()
