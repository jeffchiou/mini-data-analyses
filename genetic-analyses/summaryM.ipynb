# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib nbagg
plt.ioff()    # this stops the graphs from overwriting each other

from sympy import *
a, s, t, u, v, w, x, y, z = symbols("a, s, t, u, v, w, x, y, z")
k, m, n = symbols("k, m, n", integer=True)
f, g, h = symbols("f, g, h", cls=Function)
init_printing()

# Enable viewing of variables and expressions without print statements
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
mvec_df = pd.read_csv('mvec.csv')
mvec_df.describe()
# Out:
#        AggPercEnd  AggPercSix      LagSec      Slope         AUC    PercWBC  \
# count   36.000000   36.000000   36.000000  36.000000   36.000000  36.000000
# mean     0.766667    0.324306  229.138889  23.916667  201.111111  -0.194734
# std      0.173617    0.174897   77.745061   9.345358   63.326337   0.292090
# min      0.500000    0.000000  138.000000   9.000000  110.800000  -0.700730
# 25%      0.643750    0.225000  178.250000  19.500000  162.500000  -0.307284
# 50%      0.725000    0.337500  214.000000  23.000000  183.500000  -0.203846
# 75%      0.875000    0.431250  275.000000  27.500000  234.200000  -0.041898
# max      1.050000    0.650000  468.000000  43.000000  331.900000   0.275547
#
#          PercRBC    PercHCT    PercPLT
# count  36.000000  36.000000  36.000000
# mean   -0.171356  -0.176014   0.127047
# std     0.315597   0.315857   0.416223
# min    -0.759615  -0.762749  -0.470000
# 25%    -0.385859  -0.392710  -0.175833
# 50%    -0.118924  -0.116919   0.101313
# ...

# %%
timemvec_df = mvec_df[mvec_df['Adjustment']=='Time']
# wt_only = timemvec_df[timemvec_df['Genotype']=='WT']
lag_plt = sns.boxplot(x="Genotype",y="LagSec", data=timemvec_df)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="AggPercEnd", data=timemvec_df)
plt.show()
plt.figure()
sns.swarmplot(x="Genotype",y="AggPercEnd", data=timemvec_df)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="AggPercSix", data=timemvec_df)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="Slope", data=timemvec_df)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="AUC", data=timemvec_df)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="PercWBC", data=timemvec_df)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="PercRBC", data=timemvec_df)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="PercHCT", data=timemvec_df)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="PercPLT", data=timemvec_df)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
