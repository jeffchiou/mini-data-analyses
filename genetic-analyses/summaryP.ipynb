# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

# %%
paec_df = pd.read_csv('paec.csv')
paec_df.describe()
# Out:
#        AggPercEnd  AggPercSix      LagSec       Slope         AUC     PercWBC  \
# count  126.000000  126.000000  126.000000  126.000000  126.000000  126.000000
# mean     0.683929    0.242460  217.753968   16.500000  167.417460    0.145385
# std      0.165392    0.170888  115.091733    8.062506   58.925849    0.277294
# min      0.125000    0.000000   39.000000    4.000000    3.900000   -0.678300
# 25%      0.625000    0.075000  131.250000    7.000000  131.325000    0.031022
# 50%      0.700000    0.237500  202.000000   18.000000  169.450000    0.177969
# 75%      0.800000    0.400000  272.500000   24.000000  215.400000    0.361538
# max      1.000000    0.600000  754.000000   30.000000  284.000000    0.639381
#
#           PercRBC     PercHCT     PercPLT
# count  126.000000  126.000000  126.000000
# mean     0.200522    0.184347    0.083375
# std      0.270024    0.258834    0.367940
# min     -0.656315   -0.657767   -0.280000
# 25%      0.048077    0.039911   -0.178161
# ...

# %%
timepaec_df = paec_df[paec_df['Adjustment']=='Time']
# %matplotlib notebook
lag_plt = sns.boxplot(x="Genotype",y="LagSec", data=timepaec_df)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="AggPercEnd", data=timepaec_df)
plt.figure()
sns.swarmplot(x="Genotype",y="AggPercEnd", data=timepaec_df)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="AggPercSix", data=timepaec_df)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="Slope", data=timepaec_df)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="AUC", data=timepaec_df)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="PercWBC", data=timepaec_df)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="PercRBC", data=timepaec_df)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="PercHCT", data=timepaec_df)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x="Genotype",y="PercPLT", data=timepaec_df)
# Out:
# <img src="data:image/png;base64,..." width="640">
